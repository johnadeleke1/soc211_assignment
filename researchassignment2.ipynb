// %% [markdown]
// ## Research assignment 2
//
// John Adeleke
//
// Educational attainment and Health Insurance Coverage of Women in Urban and Rural areas of Nigeria
//
// 02/11/2024

// %% [markdown]
// ### 1. Write a paragraph about your hypotheses
//
// The independent variables in this study are educational attainment and age while the dependent variable in this analysis is educational attainment. The control variable is respondents' type of place of residence. This control variable shows an intervening relationship between age, educational attainment and health insurance coverage. In other words, women with higher education constitute are more likely to have health insurance coverage across urban and rural areas. Nevetherless, the findings show that inequalities exist between urban and rural areas in regard to health insurance coverage. Broadly, my research interests focus health disparities in Sub-Sahara Africa, hence the relationship between educational attainmenet, age and health insurance coverage provides insight into how demographic and socioeconomic factors shapes healthcare utilization in the region.
//
// Hypothesis: Women with higher levels of educational attainment are more likely to be covered by health insurance in Nigeria

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
cd "/Users/johnadeleke/Desktop/Stats2/soc211_assignment"
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
// /Users/johnadeleke/Desktop/Stats2/soc211_assignment

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Log for Research Assignment 2.log", replace
// Out:
// (file /Users/johnadeleke/Desktop/Stats2/soc211_assignment/Log for Research
//     Assignment 2.log not found)
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  /Users/johnadeleke/Desktop/Stats2/soc211_assignment/Log for Resear
// > ch Assignment 2.log
//   log type:  text
//  opened on:  11 Feb 2024, 15:26:12

// %%
use /Users/johnadeleke/Desktop/Stats2/soc211_assignment/NGIR7BDT/NGIR7BFL.DTA

// %%
set maxvar 10000

// %% [markdown]
// ### 2. Browse the data
//
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
describe v013 v025 v106 v481
// Out:
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// v013            byte    %8.0g      V013       age in 5-year groups
// v025            byte    %8.0g      V025       type of place of residence
// v106            byte    %8.0g      V106       highest educational level
// v481            byte    %8.0g      V481       covered by health insurance

// %%
codebook v013 v025 v106 v481
// Out:
// -------------------------------------------------------------------------------
// v013                                                       age in 5-year groups
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: V013
//
//                  Range: [1,7]                         Units: 1
//          Unique values: 7                         Missing .: 0/41,821
//
//             Tabulation: Freq.   Numeric  Label
//                         8,423         1  15-19
//                         6,844         2  20-24
//                         7,203         3  25-29
//                         5,997         4  30-34
//                         5,406         5  35-39
//                         4,057         6  40-44
//                         3,891         7  45-49
//
// -------------------------------------------------------------------------------
// ...

// %%
keep v013 v025 v106 v481

// %%
tab v013
tab v025
tab v106
tab v481
// Out:
//      age in |
//      5-year |
//      groups |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       15-19 |      8,423       20.14       20.14
//       20-24 |      6,844       16.36       36.51
//       25-29 |      7,203       17.22       53.73
//       30-34 |      5,997       14.34       68.07
//       35-39 |      5,406       12.93       81.00
//       40-44 |      4,057        9.70       90.70
//       45-49 |      3,891        9.30      100.00
// ------------+-----------------------------------
//       Total |     41,821      100.00
//
//     type of |
//    place of |
//   residence |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       urban |     16,984       40.61       40.61
//       rural |     24,837       59.39      100.00
// ------------+-----------------------------------
//       Total |     41,821      100.00
//
//      highest |
//  educational |
// ...

// %% [markdown]
// ### 3. Write a note summarizing what you learned from browsing the data
//
// [your note here]

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// [your note here]

// %%
histogram v481, frequency title("Health insurance coverage (Dependent variable)")
// Out:
// (bin=46, start=0, width=.02173913)

// %%
histogram v013, frequency title("Age (Independent Variable)")
// Out:
// (bin=46, start=1, width=.13043478)

// %%
histogram v025, frequency title("Type of place of residence (Control for Interverning relationship)")
// Out:
// (bin=46, start=1, width=.02173913)

// %%
histogram v106, frequency title("Highest educational level (Independent variable)")
// Out:
// (bin=46, start=0, width=.06521739)

// %% [markdown]
// The above histograms show the frequency distribution for each of the variables in this analysis. The histogram titled :age" shows the number of women within each age range while the variable titled "type of place of residence" shows the number of respondents that reside in eaither of urban or rural areas which shows that more of the women in this study reside in rural areas. The variable titled "highest educational level" represents the highest level of education obtained by women in our study. the histogram shows that most of the respondents had a secondary or no education while relatively lower numbers of respondents had primary or higher education. The histogram of the dependent varibale titled "health insurance covergae" represents the number of respondents with or without health insurance coverage. This shows that almost all of the women in this study do not have any form of health insurance coverage while less than 3% have some kind of health insurance coverage.
//
// Type of place of residence controls for intervening relationship. This variable mediates mainly between educational attainment and health insurance coverage. In other words, whether educational attainment determines if a woman gets health insurance coverage can be explained urban and rural dichotomy. People in urban areas have access to information on health insurance and in close proximity to healthcare facilities and jobs that prioritize their employees' health insurance coverage.

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// [your note here]

// %%
foreach x of varlist v013 v025 v106 v481 {
    replace `x'=. if `x'==.i | `x'==.n | `x'==.d
    tab `x', missing
}
// Out:
// (0 real changes made)
//
//      age in |
//      5-year |
//      groups |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       15-19 |      8,423       20.14       20.14
//       20-24 |      6,844       16.36       36.51
//       25-29 |      7,203       17.22       53.73
//       30-34 |      5,997       14.34       68.07
//       35-39 |      5,406       12.93       81.00
//       40-44 |      4,057        9.70       90.70
//       45-49 |      3,891        9.30      100.00
// ------------+-----------------------------------
//       Total |     41,821      100.00
// (0 real changes made)
//
//     type of |
//    place of |
//   residence |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       urban |     16,984       40.61       40.61
//       rural |     24,837       59.39      100.00
// ------------+-----------------------------------
//       Total |     41,821      100.00
// ...

// %% [markdown]
// ### 6. Make a relevant bivariate table and graph for your study
//
// Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
graph hbar (mean) v481, over(v106) title("Educational attainmment and health insurance coverage")
tab v481 v106
// Out:
// covered by |
//     health |          highest educational level
//  insurance | no educat    primary  secondary     higher |     Total
// -----------+--------------------------------------------+----------
//         no |    14,287      6,334     16,311      3,772 |    40,704
//        yes |       111         49        387        570 |     1,117
// -----------+--------------------------------------------+----------
//      Total |    14,398      6,383     16,698      4,342 |    41,821

// %%
graph hbar (mean) v481, over(v013) title("Age and health insurance coverage")
tab v481 v013
// Out:
// covered by |
//     health |                  age in 5-year groups
//  insurance |     15-19      20-24      25-29      30-34      35-39 |     Total
// -----------+-------------------------------------------------------+----------
//         no |     8,277      6,721      7,050      5,790      5,178 |    40,704
//        yes |       146        123        153        207        228 |     1,117
// -----------+-------------------------------------------------------+----------
//      Total |     8,423      6,844      7,203      5,997      5,406 |    41,821
//
//
// covered by |
//     health | age in 5-year groups
//  insurance |     40-44      45-49 |     Total
// -----------+----------------------+----------
//         no |     3,912      3,776 |    40,704
//        yes |       145        115 |     1,117
// -----------+----------------------+----------
//      Total |     4,057      3,891 |    41,821

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %%
codebook v013
sum v013
// Out:
// -------------------------------------------------------------------------------
// v013                                                       age in 5-year groups
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: V013
//
//                  Range: [1,7]                         Units: 1
//          Unique values: 7                         Missing .: 0/41,821
//
//             Tabulation: Freq.   Numeric  Label
//                         8,423         1  15-19
//                         6,844         2  20-24
//                         7,203         3  25-29
//                         5,997         4  30-34
//                         5,406         5  35-39
//                         4,057         6  40-44
//                         3,891         7  45-49
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// ...

// %%
graph hbar (mean) v481, over(v106) by(v013) title("Partial bivariate graph")

// %%
graph hbar (mean) v481, over(v106) by(v025) title("Partial bivariate graph")

// %%
graph hbar (mean) v481, over(v106) by(v025) title("Partial bivariate graph")

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
// The bivariate graphs show that there is correlation between educational attainment and health insurance coverage.The graphs show strong relationship between highest levels of education and health insurance coverage which conforms with my hypothesis that women with higher levels of education are like to be covered by health insurance in Nigeria. Even when one controlled for age and type of place of residence, the findings still show that women with higher levels of education, across different age groups and place of residence, are likely to have health insurance coverage. This shows that type of place of residence or age do not show an intervening relationships because the findings remain the same after controlling for these variables.
//
// I guess this is due to the fact that health insurance coverage in Nigeria is provided by government ministries, egencies and parastatals, and corporate employers for thie employees. It would be interesting to see how unemployment status and type of employment can influence this model.
